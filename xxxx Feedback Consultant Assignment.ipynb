# %%
import pandas as pd
import numpy as np

# %%
sentiment = pd.read_csv('C:/Users/Administrator/Desktop/banking analytics/sentiment.csv')
sentiment.shape
# Out:
# (12936, 4)

# %%
sentiment.head(10)
# Out:
#    RESPONSEID                      Word 1                      Word 2  \
# 0       71517  Good place to start career         Proud to work with
# 1       71140        Friendly environment  Good support from Managers
# 2       69933           Employee friendly             Good Management
# 3       75074                 is the best                         NaN
# 4       69559       Easy to complete task           Improve skill set
# 5       71600    Nice Environment to work                         NaN
# 6       69954             Time Management                  Discipline
# 7      101421                      Chandu                      Chandu
# 8      101422                           1                           2
# 9       69584               Shift Timings         Good appraisal Hike
#
#                            Word 3
# 0                             NaN
# 1                          Growth
# 2                      Supportive
# 3                             NaN
# 4  Appropriating employees talent
# 5                             NaN
# 6                Work environment
# 7                          Chandu
# 8                               3
# 9                             NaN

# %%
#lets start working

#creating copy for any changes
sentiment_copy = sentiment.copy()

sentiment_copy = sentiment.drop('RESPONSEID', axis = 1)
sentiment_copy.shape
# Out:
# (12936, 3)

# %%
#importing required libraries for texts analysis
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

#getting rid of warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Some text cleaning for sentiment analysis.

docs_word_1 = sentiment_copy['Word 1'].fillna('').str.lower().str.replace('[^a-z ]','')
docs_word_2 = sentiment_copy['Word 2'].fillna('').str.lower().str.replace('[^a-z ]','')
docs_word_3 = sentiment_copy['Word 3'].fillna('').str.lower().str.replace('[^a-z ]','')

#removing stopwords
stopwords   = nltk.corpus.stopwords.words('english')
stemmer     = nltk.stem.PorterStemmer()

def clean_sentence(text):
    words = text.split(' ')
    words_clean = [stemmer.stem(word) for word in words if word not in stopwords]
    return ' '.join(words_clean)

docs_word_1 = docs_word_1.apply(clean_sentence)
docs_word_2 = docs_word_2.apply(clean_sentence)
docs_word_3 = docs_word_3.apply(clean_sentence)

doc = pd.concat([docs_word_1,docs_word_2,docs_word_3], axis = 1)
print(doc.shape)

doc.head(5)
#now we have cleaned data , ready for sentiment analysis.
# Out:
# (12936, 3)
#                     Word 1              Word 2                   Word 3
# 0  good place start career         proud work
# 1         friendli environ  good support manag                   growth
# 2         employe friendli          good manag                  support
# 3                     best
# 4        easi complet task    improv skill set  appropri employe talent

# %%
#creating a function for sentiment analysis

def get_sentiment(text):
    rating   = []
    rating2  = []
    rating3  = [] #list to store rating for each word columnwise
    len(rating)

    sentiment = SentimentIntensityAnalyzer()
    compound  = sentiment.polarity_scores(text)['compound']
    #compound
    rating.append(compound)
    len(rating)
    if compound > 0.05:
        return 'Positive'
    elif compound < -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# %%
#For word 1
doc['Word 1 polarity']    = doc['Word 1'].apply(get_sentiment)
doc['word_1_rating']      = rating

# %%
#creating a function for sentiment analysis
rating   = []
rating2  = []
rating3  = [] #list to store rating for each word columnwise
    
def get_sentiment(text):
    len(rating)

    sentiment = SentimentIntensityAnalyzer()
    compound  = sentiment.polarity_scores(text)['compound']
    rating2.append(compound)
    if compound > 0.05:
        return 'Positive'
    elif compound < -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# %%
print(len(rating))

print(doc.shape)
12936*3
# Out:
# 25872
# (12936, 6)
# 38808

# %%
#For word 2
doc['Word 2 polarity']  = doc['Word 2'].apply(get_sentiment)
doc['word_2_rating']    =  rating2

# %%
doc.head()
# Out:
#                     Word 1              Word 2                   Word 3  \
# 0  good place start career         proud work
# 1         friendli environ  good support manag                   growth
# 2         employe friendli          good manag                  support
# 3                     best
# 4        easi complet task    improv skill set  appropri employe talent
#
#   Word 1 polarity  word_1_rating Word 2 polarity  word_2_rating
# 0        Positive         0.4404        Positive         0.4767
# 1         Neutral         0.0000        Positive         0.6808
# 2         Neutral         0.0000        Positive         0.4404
# 3        Positive         0.6369         Neutral         0.0000
# 4         Neutral         0.0000         Neutral         0.0000

# %%
#creating a function for sentiment analysis
rating   = []
rating2  = []
rating3  = [] #list to store rating for each word columnwise
len(rating)

def get_sentiment(text):
    
    sentiment = SentimentIntensityAnalyzer()
    compound  = sentiment.polarity_scores(text)['compound']
    rating3.append(compound)
    if compound > 0.05:
        return 'Positive'
    elif compound < -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# %%
#For word 3
doc['Word 3 polarity']  = doc['Word 3'].apply(get_sentiment)
doc['word_3_rating']    =  rating3

# %%
doc['final polarity'] =  doc[['word_1_rating','word_3_rating','word_2_rating']].mean(axis = 1)

doc['final result']   = np.where(doc['final polarity'] >= 0.05,'positive','negative')
doc['final result']   = np.where(doc['final polarity'] <= -0.05,'negative',doc['final result'])
doc['final result']   = np.where((doc['final polarity'] > -0.05) & (doc['final polarity'] < 0.05) ,'neutral',doc['final result'])
doc.head(20)
# Out:
#                      Word 1                Word 2  \
# 0   good place start career           proud work
# 1          friendli environ    good support manag
# 2          employe friendli            good manag
# 3                      best
# 4         easi complet task      improv skill set
# 5         nice environ work
# 6                time manag             disciplin
# 7                    chandu                chandu
# 8
# 9                shift time     good apprais hike
# 10                job secur
# 11           great workplac     best staff member
# 12         friendli environ
# 13                  support                  help
# 14
# 15         happi come offic           enjoy work
# 16         friendli support
# 17      friendli place work  conveni place travel
# 18                     nice                  good
# 19                     nice                  good
#
#                                      Word 3 Word 1 polarity  word_1_rating  \
# 0                                                  Positive         0.4404
# 1                                    growth         Neutral         0.0000
# 2                                   support         Neutral         0.0000
# 3                                                  Positive         0.6369
# 4                   appropri employe talent         Neutral         0.0000
# 5                                                  Positive         0.4215
# 6                              work environ         Neutral         0.0000
# 7                                    chandu         Neutral         0.0000
# 8                                                   Neutral         0.0000
# 9                                                   Neutral         0.0000
# 10                                                  Neutral         0.0000
# 11                            good opportun        Positive         0.6249
# 12                                                  Neutral         0.0000
# 13                              work cultur        Positive         0.4019
# 14                                                  Neutral         0.0000
# 15                    get support whin want         Neutral         0.0000
# 16                                                 Positive         0.4019
# 17  like polici women employe safeti measur         Neutral         0.0000
# 18                                   awesom        Positive         0.4215
# 19                                   wonder        Positive         0.4215
#
#    Word 2 polarity  word_2_rating Word 3 polarity  word_3_rating  \
# 0         Positive         0.4767         Neutral         0.0000
# 1         Positive         0.6808        Positive         0.3818
# 2         Positive         0.4404        Positive         0.4019
# 3          Neutral         0.0000         Neutral         0.0000
# 4          Neutral         0.0000        Positive         0.4215
# 5          Neutral         0.0000         Neutral         0.0000
# 6          Neutral         0.0000         Neutral         0.0000
# 7          Neutral         0.0000         Neutral         0.0000
# 8          Neutral         0.0000         Neutral         0.0000
# 9         Positive         0.4404         Neutral         0.0000
# 10         Neutral         0.0000         Neutral         0.0000
# 11        Positive         0.6369        Positive         0.4404
# 12         Neutral         0.0000         Neutral         0.0000
# 13        Positive         0.4019         Neutral         0.0000
# 14         Neutral         0.0000         Neutral         0.0000
# 15        Positive         0.4939        Positive         0.4588
# 16         Neutral         0.0000         Neutral         0.0000
# 17         Neutral         0.0000        Positive         0.3612
# 18        Positive         0.4404         Neutral         0.0000
# 19        Positive         0.4404         Neutral         0.0000
#
#     final polarity final result
# 0         0.305700     positive
# 1         0.354200     positive
# 2         0.280767     positive
# 3         0.212300     positive
# 4         0.140500     positive
# 5         0.140500     positive
# 6         0.000000      neutral
# 7         0.000000      neutral
# 8         0.000000      neutral
# 9         0.146800     positive
# 10        0.000000      neutral
# 11        0.567400     positive
# 12        0.000000      neutral
# 13        0.267933     positive
# 14        0.000000      neutral
# 15        0.317567     positive
# 16        0.133967     positive
# 17        0.120400     positive
# 18        0.287300     positive
# 19        0.287300     positive

# %%
doc.to_csv('C:/Users/Administrator/Desktop/ML/submission.csv', index=False)

# %% [markdown]
# # THANK YOU ~~
